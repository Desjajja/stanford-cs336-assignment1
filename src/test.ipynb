# %%
with open('../output/merges_10000.txt', 'r', encoding='utf-8') as f:
    merge = [tuple(map(eval, line.strip().split(' '))) for line in f if line.strip()]

# %%
merge
# Out:
# [(b'h', b'e'),
#  (b'a', b'n'),
#  (b't', b'he'),
#  (b'e', b'd'),
#  (b't', b'o'),
#  (b'i', b'n'),
#  (b'r', b'e'),
#  (b'i', b't'),
#  (b'w', b'a'),
#  (b'o', b'u'),
#  (b'h', b'a'),
#  (b'T', b'he'),
#  (b'e', b'r'),
#  (b'a', b'y'),
#  (b'e', b'n'),
#  (b'o', b'm'),
#  (b'i', b's'),
#  (b'a', b'r'),
#  (b'o', b'n'),
#  (b'i', b'm'),
#  (b's', b'a'),
#  (b'i', b'd'),
#  (b'l', b'l'),
#  (b'l', b'e'),
#  (b's', b't'),
#  (b'o', b't'),
#  (b'a', b'm'),
#  (b'o', b'r'),
#  (b'i', b'r'),
#  (b'n', b'e'),
#  (b'p', b'l'),
#  (b'i', b'g'),
#  (b'a', b't'),
#  (b'H', b'e'),
#  (b'b', b'e'),
#  (b'i', b'l'),
#  (b'l', b'o'),
#  (b'a', b'll'),
#  (b'r', b'i'),
#  (b'v', b'er'),
#  (b'h', b'is'),
#  (b'd', b'ay'),
#  (b'u', b't'),
#  (b'sa', b'id'),
#  (b'T', b'im'),
#  (b'w', b'it'),
#  (b's', b'e'),
#  (b'p', b'p'),
#  (b'k', b'ed'),
#  (b'o', b'w'),
#  (b'c', b'e'),
#  (b'u', b'n'),
#  (b'k', b'e'),
#  (b'S', b'he'),
#  (b'l', b'd'),
#  (b't', b'h'),
#  (b'b', b'ig'),
#  (b'y', b'ou'),
# ...

# %%
dict((1,2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dict((1,2))
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
vocab_dict = dict(vocab)
